# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("Car_24.csv")

# %%
df1
# Out:
#      Unnamed: 0       Brand  Year Fuel_Type  KM_Driven  Ownership  \
# 0             0     Hyundai  2016    Petrol      57832          2
# 1             1        Ford  2018    Petrol      31896          1
# 2             2  Volkswagen  2016    Petrol      79370          1
# 3             3     Hyundai  2017    Petrol      46357          3
# 4             4      Maruti  2012    Diesel      88992          3
# ..          ...         ...   ...       ...        ...        ...
# 415         415     Hyundai  2017    Petrol      32345          2
# 416         416     Hyundai  2017    Petrol      32345          1
# 417         417      Maruti  2017    Petrol      84684          1
# 418         418     Hyundai  2017    Petrol      27636          2
# 419         419      Maruti  2015    Petrol      38213          1
#
#             Location  Down_Payment   Price    EMI
# 0          Bengaluru        118800  594000   9290
# 1          Bengaluru        130400  652000  10197
# ...

# %%
df = pd.read_csv("cars_24", index_col = [0])

# %%
df
# Out:
#           Brand  Year Fuel_Type  KM_Driven  Ownership         Location  \
# 0       Hyundai  2016    Petrol      57832          2        Bengaluru
# 1          Ford  2018    Petrol      31896          1        Bengaluru
# 2    Volkswagen  2016    Petrol      79370          1  Sonnappanahalli
# 3       Hyundai  2017    Petrol      46357          3        Bengaluru
# 4        Maruti  2012    Diesel      88992          3        Bengaluru
# ..          ...   ...       ...        ...        ...              ...
# 415     Hyundai  2017    Petrol      32345          2        Bengaluru
# 416     Hyundai  2017    Petrol      32345          1        Bengaluru
# 417      Maruti  2017    Petrol      84684          1        Bengaluru
# 418     Hyundai  2017    Petrol      27636          2        Bengaluru
# 419      Maruti  2015    Petrol      38213          1        Bengaluru
#
#      Down_Payment   Price    EMI
# 0          118800  594000   9290
# 1          130400  652000  10197
# ...

# %%
df.head()
# Out:
#         Brand  Year Fuel_Type  KM_Driven  Ownership         Location  \
# 0     Hyundai  2016    Petrol      57832          2        Bengaluru
# 1        Ford  2018    Petrol      31896          1        Bengaluru
# 2  Volkswagen  2016    Petrol      79370          1  Sonnappanahalli
# 3     Hyundai  2017    Petrol      46357          3        Bengaluru
# 4      Maruti  2012    Diesel      88992          3        Bengaluru
#
#    Down_Payment   Price    EMI
# 0        118800  594000   9290
# 1        130400  652000  10197
# 2        117000  585000   9149
# 3        108600  543000   8493
# 4        111000  555000   8680

# %% [markdown]
# ## CONTINUOUS TO CONTINUOUS VARIABLES - Scatterplot

# %% [markdown]
# ### Scatterplot for Price Analysis

# %%
#Scatter plot on price and ownership
plt.scatter(df['Ownership'], df['Price'])

# %%
#scatter plot on year and price
plt.scatter(df['Year'], df['Price'])

# %%
#scatter plot on km driven and price
plt.scatter(df['KM_Driven'], df['Price'])

# %%
#scatter plot on down payment and price
plt.scatter(df['Down_Payment'], df['Price'])

# %%
#scatter plot on emi and price
plt.scatter(df['EMI'],df['Price'])

# %%
#pair plot on data
sns.pairplot(data = df)

# %%
#correaltion between continuous variables
df[['Price','EMI','Ownership','KM_Driven','Price']].corr()
# Out:
#               Price       EMI  Ownership  KM_Driven     Price
# Price      1.000000  1.000000  -0.139873  -0.266096  1.000000
# EMI        1.000000  1.000000  -0.139835  -0.266025  1.000000
# Ownership -0.139873 -0.139835   1.000000  -0.066057 -0.139873
# KM_Driven -0.266096 -0.266025  -0.066057   1.000000 -0.266096
# Price      1.000000  1.000000  -0.139873  -0.266096  1.000000

# %%
#HeatMap for continuous variables
sns.heatmap(df[['Price','EMI','Ownership','KM_Driven','Price']].corr(), annot = True)
# Out:
# <Axes: >

# %%
#barplot for ownership and year
sns.barplot(x = 'Ownership', y= 'Price', data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
#barplot for price and km driven
sns.barplot(x = 'KM_Driven', y= 'Price', data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
#barplot for emi and price
sns.barplot(x = 'EMI', y= 'Price', data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
#bar plot for downpayment and price
sns.barplot(x = 'Down_Payment', y= 'Price', data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
#barplot for kmdriven and downpayment
sns.barplot(x = 'KM_Driven', y= 'Down_Payment', data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
#bar plot for emi and km driven
sns.barplot(x = 'EMI', y= 'KM_Driven', data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
#bar plot for ownership  and km driven
sns.barplot(x = 'Ownership', y= 'KM_Driven', data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
#bar plot for ownership and downpayment
sns.barplot(x = 'Ownership', y= 'Down_Payment', data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
#barplot for ownership and emi
sns.barplot(x = 'Ownership', y= 'EMI', data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
#bar plot for emi and downpayment
sns.barplot(x = 'EMI', y= 'Down_Payment', data = df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## CATEGORICAL TO CATEGORICAL - Crosstab

# %%
#creating bargraph with crosstab
crosstab = pd.crosstab(df['Brand'], df['Year'])
crosstab
# Out:
# Year        2012  2013  2014  2015  2016  2017  2018  2021
# Brand
# Ford           0     0     0     0     0     0    21     0
# Honda          0     0     0     0     0    21     0     0
# Hyundai        0    21     0     0    21   126    21     0
# Maruti        21     0    42    21     0    21     0     0
# Nissan         0     0     0     0     0     0     0    21
# Renault        0     0     0    21     0     0     0     0
# Tata           0     0     0     0     0     0    21     0
# Volkswagen     0     0     0     0    21     0     0     0

# %%
crosstab.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='Brand'>

# %%
#cross tab with year and fueltype
crosstab = pd.crosstab(df['Fuel_Type'], df['Year'])
crosstab
# Out:
# Year       2012  2013  2014  2015  2016  2017  2018  2021
# Fuel_Type
# Diesel       21     0     0    21     0     0     0     0
# Petrol        0    21    42    21    42   168    63    21

# %%
crosstab.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
#crosstab with fueltype and location
crosstab = pd.crosstab(df['Location'], df['Fuel_Type'])
crosstab
# Out:
# Fuel_Type        Diesel  Petrol
# Location
# Bengaluru            42     336
# Sonnappanahalli       0      42

# %%
crosstab.plot(kind= 'bar', stacked = True)
# Out:
# <Axes: xlabel='Location'>

# %%
#crosstab with fueltypw and brand
crosstab = pd.crosstab(df['Fuel_Type'], df['Brand'])
crosstab
# Out:
# Brand      Ford  Honda  Hyundai  Maruti  Nissan  Renault  Tata  Volkswagen
# Fuel_Type
# Diesel        0      0        0      21       0       21     0           0
# Petrol       21     21      189      84      21        0    21          21

# %%
crosstab.plot(kind= 'bar', stacked = True)
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
#crosstab with location and brand
crosstab = pd.crosstab(df['Location'], df['Brand'])
crosstab
# Out:
# Brand            Ford  Honda  Hyundai  Maruti  Nissan  Renault  Tata  \
# Location
# Bengaluru          21      0      189     105      21       21    21
# Sonnappanahalli     0     21        0       0       0        0     0
#
# Brand            Volkswagen
# Location
# Bengaluru                 0
# Sonnappanahalli          21

# %%
crosstab.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='Location'>

# %%
#crosstab with year and loction
crosstab = pd.crosstab(df['Year'], df['Location'])
crosstab
# Out:
# Location  Bengaluru  Sonnappanahalli
# Year
# 2012             21                0
# 2013             21                0
# 2014             42                0
# 2015             42                0
# 2016             21               21
# 2017            147               21
# 2018             63                0
# 2021             21                0

# %%
crosstab.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ## CATEGORICAL TO CONTINUOUS DATA

# %%
#Box plot for price and brand
sns.boxplot(x= df['Brand'], y=df['Price'])
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %%
#box plot for year and  price 
sns.boxplot(x=df['Year'],y=df['Price'])
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %%
#boxplot for price nad fuel type
sns.boxplot(x = df['Fuel_Type'], y=df['Price'])
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Price'>

# %%
#boxplot for price and location
sns.boxplot(x=df['Location'], y=df['Price'])
# Out:
# <Axes: xlabel='Location', ylabel='Price'>

# %%
#Box plot for km driven and brand
sns.boxplot(x=df['Brand'],y=df['KM_Driven'])
# Out:
# <Axes: xlabel='Brand', ylabel='KM_Driven'>

# %%
#box plot on kmdriven and year
sns.boxplot(x=df['Year'],y = df['KM_Driven'])
# Out:
# <Axes: xlabel='Year', ylabel='KM_Driven'>

# %%
#boxplot on kmdriven and location
sns.boxplot(x=df['Location'],y=df['KM_Driven'])
# Out:
# <Axes: xlabel='Location', ylabel='KM_Driven'>

# %%
#boxplot on kmdriven and fueltype
sns.boxplot(x=df['Fuel_Type'],y=df['KM_Driven'])
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='KM_Driven'>

# %%
#boxplot on downpayment and brand
sns.boxplot(x=df['Brand'],y=df['Down_Payment'])
# Out:
# <Axes: xlabel='Brand', ylabel='Down_Payment'>

# %%
#boxplot on downpayment and year
sns.boxplot(x=df['Year'],y=df['Down_Payment'])
# Out:
# <Axes: xlabel='Year', ylabel='Down_Payment'>

# %%
#box plot for fueltype and downpayment
sns.boxplot(x=df['Fuel_Type'],y=df['Down_Payment'])
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Down_Payment'>

# %%
#boxplot for downpayment and location
sns.boxplot(x=df['Location'],y=df['Down_Payment'])
# Out:
# <Axes: xlabel='Location', ylabel='Down_Payment'>

# %%
#box plot between Emi and brand
sns.boxplot(x=df['Brand'],y=df['EMI'])
# Out:
# <Axes: xlabel='Brand', ylabel='EMI'>

# %%
#box plot for emi and year
sns.boxplot(x=df['Year'],y=df['EMI'])
# Out:
# <Axes: xlabel='Year', ylabel='EMI'>

# %%
#ownership between emi and fueltype
sns.boxplot(x=df['Fuel_Type'],y=df['EMI'])
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='EMI'>

# %%
#boxplot for emi and location
sns.boxplot(x=df['Location'],y=df['EMI'])
# Out:
# <Axes: xlabel='Location', ylabel='EMI'>

# %%
#boxplot for ownership and brand
sns.boxplot(x=df['Brand'],y=df['Ownership'])
# Out:
# <Axes: xlabel='Brand', ylabel='Ownership'>

# %%
#boxplot for ownership and year
sns.boxplot(x=df['Ownership'],y=df['Year'])
# Out:
# <Axes: xlabel='Ownership', ylabel='Year'>

# %%
#boxplot for ownership and fueltype
sns.boxplot(x=df['Fuel_Type'],y=df['Ownership'])
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Ownership'>

# %%
#boxplot for ownership and location
sns.boxplot(x=df['Location'],y=df['Ownership'])
# Out:
# <Axes: xlabel='Location', ylabel='Ownership'>

# %%
#boxplot for price,fueltype and ownership
sns.boxplot(x=df['Fuel_Type'],y=df['Price'], hue=df['Ownership'])
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Price'>

# %%
#boxplot for price,brand and ownership
sns.boxplot(x=df['Brand'],y=df['Price'], hue=df['Ownership'])
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %%
#boxplot for price,year and ownership
sns.boxplot(x=df['Year'],y=df['Price'], hue=df['Ownership'])
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %%
#boxplot for price,location and ownership
sns.boxplot(x=df['Location'],y=df['Price'], hue=df['Ownership'])
# Out:
# <Axes: xlabel='Location', ylabel='Price'>

# %%
#boxplot for year,price and fueltype
sns.boxplot(x=df['Year'],y=df['Price'], hue=df['Fuel_Type'])
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %%
#boxplot for brand,price,Fueltype
sns.boxplot(x=df['Brand'],y=df['Price'], hue=df['Fuel_Type'])
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %%
#boxplot for Location,price,Fueltype
sns.boxplot(x=df['Location'],y=df['Price'], hue=df['Fuel_Type'])
# Out:
# <Axes: xlabel='Location', ylabel='Price'>
